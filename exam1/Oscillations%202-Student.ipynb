# %% [markdown]
# ### Driven oscillator and resonance
#
# Using the tools developed in the previous in-class exercises, solve the *damped, driven harmonic oscillator* system described by the equation:
#
# $ \frac{d^2x}{dt^2} + 2\gamma\omega_0\frac{dx}{dt}+\omega_0^2x=F_dcos(\omega_d t)$
#
# use the following constants and intial values:
# * $\gamma$ = .3
# * $\omega_0$ = 1.0
# * $F_d$ = $\omega_0^2$
# * $\omega_d = m\omega_0$
# * $0.5<m<1.5$
# * Initial value: $x_0$ = 1
# * Initial value: $v_0$ = 0
#
# Plot the solutions for $\omega_d = .5\omega_0, \omega_0, 1.5\omega_0$ for 50 time units. Verify that the amplitude of the oscillation grows to the largest value if
#
# $\omega_r = \omega_0\sqrt{1-2\gamma^2}$.
#
# this phenomena is called *resonance*.

# %%
import numpy as np
import pylab as plt
from __future__ import division

# %% [markdown]
# ### Triatomic molecule
# We can use the idea of a harmonic oscillator to model the behavior of a molecule with three atoms. I will show in class that two atoms is trivially the same as a harmonic oscillator. Three atoms points the direction to analysis of many masses and springs - our objective in this unit.
#
# The equations of motion for a three particle system are as follows:
#
# $m_1 \ddot{u}_1 = -k(u_1 - u_2)$
#
# $m_2 \ddot{u}_2 = -k(u_2 - u_1)-k(u_2 - u_3)$
#
# $m_3 \ddot{u}_3 = -k(u_3 - u_2)$
#
# Solve this system of equations using the RK4 solver you previously developed. Use $k=1$, $m_1=m_3 = \frac{1}{4}$ and $m_2 = \frac{2}{5}$. Initial conditions should be $(u_1,u_2,u_3) = (-0.2,0.2,0)$ all velocities are intially zero.

# %%
from scipy import signal
# Study the documentation and figure out what the arguements of the following
# should be
# https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.signal.periodogram.html
f, Pxx_den = signal.periodogram(???,???)
plt.semilogy(f, Pxx_den)
plt.ylim([1e-4,1])
plt.xlabel('frequency [Hz]')
plt.ylabel('Power Spectra Density')
plt.show()
